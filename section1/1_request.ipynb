# %%
# %pip install anthropic dotenv
# Out:
# /bin/bash: /home/hossam/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

print("dotenv found a file:", load_dotenv())          # False = no .env located
print("key in env:", bool(os.environ.get("ANTHROPIC_API_KEY")))
# Out:
# dotenv found a file: True
# key in env: True

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model= "claude-sonnet-4-5"

# %%
message=client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            'role':'user',
            'content':'tell me, what is quantum computing in one line'
        }
    ]
)

# %%
message
# Out:
# Message(id='msg_011Ce6QghQYoKYFAk8AkKjqm', container=None, content=[TextBlock(citations=None, text='Quantum computing uses quantum mechanical phenomena like superposition and entanglement to process information in ways that can solve certain problems exponentially faster than classical computers.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=34, output_tokens_details=None, server_tool_use=None, service_tier='standard'))

# %%
message.content[0].text
# Out:
# 'Quantum computing uses quantum mechanical phenomena like superposition and entanglement to process information in fundamentally different ways than classical computers, potentially solving certain complex problems exponentially faster.'

# %%
def add_user_message(messages,text):
    user_message={'role':'user','content':text}
    messages.append(user_message)
    
def add_assistant_message(messages,text):
    assistant_message={'role':'assistant','content':text}
    messages.append(assistant_message)
    
def chat(messages):
    answer=client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages
    )
    return answer.content[0].text

# %%
messages=[]

add_user_message(messages,"what is quantum computing in one sentence")

messages
# Out:
# [{'role': 'user', 'content': 'what is quantum computing in one sentence'}]

# %%
answer = chat(messages)
answer
# Out:
# 'Quantum computing is a type of computing that uses quantum mechanical phenomena like superposition and entanglement to perform calculations that would be impossible or impractical for classical computers.'

# %%
add_assistant_message(messages,answer)
messages
# Out:
# [{'role': 'user', 'content': 'what is quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': 'Quantum computing is a type of computing that uses quantum mechanical phenomena like superposition and entanglement to perform calculations that would be impossible or impractical for classical computers.'}]

# %%
add_user_message(messages,"write another sentence")
messages
# Out:
# [{'role': 'user', 'content': 'what is quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': 'Quantum computing is a type of computing that uses quantum mechanical phenomena like superposition and entanglement to perform calculations that would be impossible or impractical for classical computers.'},
#  {'role': 'user', 'content': 'write another sentence'}]

# %%
answer=chat(messages)
answer
# Out:
# 'Quantum computers have the potential to revolutionize fields like cryptography, drug discovery, and artificial intelligence by solving complex optimization problems exponentially faster than traditional computers.'

# %%
add_assistant_message(messages,answer)

# %%
messages
# Out:
# [{'role': 'user', 'content': 'what is quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': 'Quantum computing is a type of computing that uses quantum mechanical phenomena like superposition and entanglement to perform calculations that would be impossible or impractical for classical computers.'},
#  {'role': 'user', 'content': 'write another sentence'},
#  {'role': 'assistant',
#   'content': 'Quantum computers have the potential to revolutionize fields like cryptography, drug discovery, and artificial intelligence by solving complex optimization problems exponentially faster than traditional computers.'}]

# %%
messages=[]
while(True):
    user_input= input()
    print(user_input)
    
    add_user_message(messages,user_input)
    
    answer=chat(messages)
    print(answer)
    add_assistant_message(messages,answer)
# Out:
# what is 1+1
# 1 + 1 = 2
# what is 2 more
# 2 + 2 = 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 3
#       1 messages=[]
#       2 while(True):
# ----> 3     user_input= input()
#       4     print(user_input)
#       6     add_user_message(messages,user_input)
#
# File ~/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File ~/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
# ...
